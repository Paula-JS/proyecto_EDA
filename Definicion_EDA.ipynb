# %% [markdown]
# # INFORMACIÓN DEL PROYECTO

# %% [markdown]
# ### TÍTULO

# %% [markdown]
# Análisis EDA, de la zonas más rentables para constituir una empresa de viviendas prefabricadas.

# %% [markdown]
# ### TEMA

# %% [markdown]
# El análisis con título anterior, se centrará en facilitarle a nuestro cliente, una empresario que quiere apostar por montar una empresa de viviendas prefabricadas, la ubicación más rentable para constiturir su empresa en España.
#
# Para ello, nos centraremos en cuatro factores fundamentales, como son, las caraterísiticas de las viviendas prefabricadas, el precio por metro cuadrado, la climatología y la cantidad de suelo urbanizable disponible.

# %% [markdown]
# ### HIPÓTESIS

# %% [markdown]
# Define aquí lo que será la hipótesis de tu proyecto.
# Puede que tengas más de una, pero tu proyecto lo harás teniendo una principal hipótesis.

# %% [markdown]
# H1. Las zonas periféricas de las ciudades tienen el metro cuadrado más económico.
#
# H2. Las viviendas prefabricadas no suelen encontrarse en climas fríos, como el norte de España.
#
# H3. Las viviendas prefabricas suelen encontrarse en climas más cálidos.
#
# H4. Hay más disponibilidad de suelo urbanizable en el norte de España.
#
# H5. Centrarse en los nichos de mercado puede tener éxito.

# %% [markdown]
# ## OBTENCIÓN DE LOS DATOS

# %% [markdown]
# ### DATASETS Y FUENTES ALTERNATIVAS DE DATOS

# %% [markdown]
# Incluye aquí una breve descripción del dataset o datasets de los que partirás para poder evaluar tu hipótesis. <br>
# También incluye el origen de estos datos y su fuente.

# %% [markdown]
# Como se ha comentado anteriormente, partiremos de 4 características para encontrar la zona más rentable, por lo que se neceistarán diferentes fuentes:
#
# Caracterísiticas del producto: las cuales se extraerán de diferentes empresas que se dedican a la fabricación de viviendas prefabricadas como Casas Baratas (https://casasbaratas.com.es/?gad_source=1&gclid=Cj0KCQjw7Py4BhCbARIsAMMx-_Ljs86tceUjKEGA2ZDLMZiYTFsBuXZ61Xh7ke3dpVqlmNUMdj_NJPYaAsd3EALw_wcB), Herdel (https://www.construccionmodularherdel.com/vivienda-modular-industrializada-prefabricada/), Tini Living (https://tiniliving.com/modelos/)
#
# Precio por metro cuadrado: datasets del gobierno.
#
# Climatología: datasets de Aemet
#
# Estadística de precios del suelo urbano: https://apps.fomento.gob.es/BoletinOnline2/?nivel=2&orden=36000000
#
# Suelo urbanizable en España: https://terrenos.es/parcelas/venta-urbanizable-de-banco

# %% [markdown]
# Muestra mediante un head() los principales datasets con los que vas a trabajar

# %% [markdown]
# Por lo pronto, partiremos del precio por metro cuadrado del suelo urbano, a partir de aquí, iremos acontando la búsqueda según vayamos obteniendo los datos

# %%
import pandas as pd

# %%
url = "/Users/paulajimenezsuaza/repos/proyecto_EDA/Bases de datos/df_precio_metro_cuadrado - Hoja 1.csv"
sep = "," 



precio_metro_cuadrado = pd.read_csv(url, sep=sep)
precio_metro_cuadrado
# Out:
#          Unnamed: 0 Año 2004 Unnamed: 2 Unnamed: 3 Unnamed: 4 Año 2005  \
# 0               NaN       1º         2º         3º         4º       1º
# 1    TOTAL NACIONAL    206,5      226,4      227,1      247,3    258,6
# 2         Andalucía    174,8      193,2      201,9      193,4    213,4
# 3           Almería    221,8      361,2        316      446,3    492,5
# 4             Cádiz    174,4      225,7      238,5      211,6    192,4
# ..              ...      ...        ...        ...        ...      ...
# 58            Álava    345,3        364      357,9      420,2    314,9
# 59        Guipúzcoa    443,3      437,6      374,7      382,6    341,9
# 60          Vizcaya      262      298,6      307,7      324,1      328
# 61       Rioja (La)    184,6      271,8      299,1      280,1      267
# 62  Ceuta y Melilla    270,4      339,1      449,5      566,3    674,6
#
#    Unnamed: 6 Unnamed: 7 Unnamed: 8 Año 2006  ... Unnamed: 75 Unnamed: 76  \
# ...
